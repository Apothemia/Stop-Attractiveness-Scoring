# %%
import pandas as pd

# %%
df_pqt = pd.read_parquet(
    'data/UrbanBus/Feb_2018/2018-02-01.parquet',
    engine='pyarrow'
)
df_pqt
# Out:
#          Card_Number Card_Type Travel_Mode Bus_Service_Number Direction  \
# 0               6448         A         Bus           SER_52f1     Start
# 1               7029         S         Bus           SER_52f1     Start
# 2               7348        SC         Bus           SER_52f1     Start
# 3               7475         A         Bus           SER_52f1     Start
# 4               7708        SC         Bus           SER_52f1     Start
# ...              ...       ...         ...                ...       ...
# 6461988    184084274         A         Bus           SER_620c     Start
# 6461989    184084276         A         Bus           SER_620c     Start
# 6461990    184084277         A         Bus           SER_620c     Start
# 6461991    184084278        SC         Bus           SER_620c     Start
# 6461992    184084279         A         Bus           SER_620c     Start
#
#         Bus_Trip_Num Bus_Reg_Num Boarding_stop_stn Alighting_stop_stn  \
# ...
